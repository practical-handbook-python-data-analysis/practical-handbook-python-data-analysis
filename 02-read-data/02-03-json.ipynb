# %% [markdown]
# # JSON形式

# %% [markdown]
# ## JSON形式の特徴

# %% [markdown]
# ## データサンプル

# %%
from urllib.request import urlopen
import os

# app_id = os.environ["ESTAT_APP_ID"]  # アプリケーションIDをOSの環境変数から取得

url = f"http://api.e-stat.go.jp/rest/3.0/app/json/getStatsData?appId=528ef50eee0854bda127ee70b47045020e73658d&lang=J&statsDataId=0003443838&metaGetFlg=Y&cntGetFlg=N&explanationGetFlg=Y&annotationGetFlg=Y&sectionHeaderFlg=1&replaceSpChars=0"
with urlopen(url) as uf:
    with open("data/population-202302.json", "wb") as f:
        f.write(uf.read())

# %% [markdown]
# # JSON形式を扱うライブラリ

# %% [markdown]
# # jsonライブラリを使う

# %%
import json

with open("data/population-202302.json", "r") as f:
    data = json.load(f)

type(data)
# Out:
# dict

# %%
data
# Out:
# {'GET_STATS_DATA': {'RESULT': {'STATUS': 0,
#    'ERROR_MSG': '正常に終了しました。',
#    'DATE': '2024-05-11T20:48:13.014+09:00'},
#   'PARAMETER': {'LANG': 'J',
#    'STATS_DATA_ID': '0003443838',
#    'DATA_FORMAT': 'J',
#    'START_POSITION': 1,
#    'METAGET_FLG': 'Y',
#    'EXPLANATION_GET_FLG': 'Y',
#    'ANNOTATION_GET_FLG': 'Y',
#    'REPLACE_SP_CHARS': 0,
#    'CNT_GET_FLG': 'N',
#    'SECTION_HEADER_FLG': 1},
#   'STATISTICAL_DATA': {'RESULT_INF': {'TOTAL_NUMBER': 2349,
#     'FROM_NUMBER': 1,
#     'TO_NUMBER': 2349},
#    'TABLE_INF': {'@id': '0003443838',
#     'STAT_NAME': {'@code': '00200524', '$': '人口推計'},
#     'GOV_ORG': {'@code': '00200', '$': '総務省'},
#     'STATISTICS_NAME': '人口推計 各月1日現在人口 概算値',
#     'TITLE': {'@no': '001',
#      '$': '概算値 年齢（５歳階級），男女，月別人口－総人口（各月１日現在）-令和２年国勢調査基準-'},
#     'CYCLE': '月次',
#     'SURVEY_DATE': 0,
#     'OPEN_DATE': '2024-04-22',
#     'SMALL_AREA': 0,
#     'COLLECT_AREA': '全国',
#     'MAIN_CATEGORY': {'@code': '02', '$': '人口・世帯'},
#     'SUB_CATEGORY': {'@code': '01', '$': '人口'},
#     'OVERALL_TOTAL_NUMBER': 2268,
#     'UPDATED_DATE': '2024-04-22',
#     'STATISTICS_NAME_SPEC': {'TABULATION_CATEGORY': '人口推計',
#      'TABULATION_SUB_CATEGORY1': '各月1日現在人口',
#      'TABULATION_SUB_CATEGORY2': '概算値'},
#     'DESCRIPTION': '',
#     'TITLE_SPEC': {'TABLE_CATEGORY': '概算値',
#      'TABLE_NAME': '年齢（５歳階級），男女，月別人口－総人口（各月１日現在）-令和２年国勢調査基準-'}},
#    'CLASS_INF': {'CLASS_OBJ': [{'@id': 'tab',
#       '@name': '表章項目',
#       'CLASS': {'@code': '001', '@name': '人口', '@level': '', '@unit': '万人'}},
#      {'@id': 'cat01',
#       '@name': '人口',
#       'CLASS': {'@code': '001', '@name': '総人口', '@level': '1'}},
#      {'@id': 'cat02',
#       '@name': '男女別',
#       'CLASS': [{'@code': '000', '@name': '男女計', '@level': '1'},
#        {'@code': '001', '@name': '男', '@level': '1'},
#        {'@code': '002', '@name': '女', '@level': '1'}]},
#      {'@id': 'cat03',
#       '@name': '年齢5歳階級',
#       'CLASS': [{'@code': '01000', '@name': '総数', '@level': '1'},
#        {'@code': '01001', '@name': '0～4歳', '@level': '1'},
#        {'@code': '01002', '@name': '5～9歳', '@level': '1'},
#        {'@code': '01003', '@name': '10～14歳', '@level': '1'},
#        {'@code': '01004', '@name': '15～19歳', '@level': '1'},
#        {'@code': '01005', '@name': '20～24歳', '@level': '1'},
#        {'@code': '01006', '@name': '25～29歳', '@level': '1'},
#        {'@code': '01007', '@name': '30～34歳', '@level': '1'},
#        {'@code': '01008', '@name': '35～39歳', '@level': '1'},
#        {'@code': '01009', '@name': '40～44歳', '@level': '1'},
#        {'@code': '01010', '@name': '45～49歳', '@level': '1'},
#        {'@code': '01011', '@name': '50～54歳', '@level': '1'},
#        {'@code': '01012', '@name': '55～59歳', '@level': '1'},
#        {'@code': '01013', '@name': '60～64歳', '@level': '1'},
#        {'@code': '01014', '@name': '65～69歳', '@level': '1'},
#        {'@code': '01015', '@name': '70～74歳', '@level': '1'},
#        {'@code': '01016', '@name': '75～79歳', '@level': '1'},
#        {'@code': '01017', '@name': '80～84歳', '@level': '1'},
#        {'@code': '01018', '@name': '85～89歳', '@level': '1'},
#        {'@code': '01019', '@name': '90～94歳', '@level': '1'},
#        {'@code': '01020', '@name': '95～99歳', '@level': '1'},
#        {'@code': '01021', '@name': '100歳以上', '@level': '1'},
#        {'@code': '02000', '@name': '（再掲）15歳未満', '@level': '1'},
#        {'@code': '01023', '@name': '（再掲）15～64歳', '@level': '1'},
#        {'@code': '01024', '@name': '（再掲）65歳以上', '@level': '1'},
#        {'@code': '01026',
#         '@name': '（再掲）うち75歳以上',
#         '@level': '2',
#         '@parentCode': '01024'},
#        {'@code': '01027',
#         '@name': '（再掲）うち85歳以上',
#         '@level': '2',
#         '@parentCode': '01024'}]},
#      {'@id': 'cat04',
#       '@name': '概算値',
#       'CLASS': {'@code': '01', '@name': '概算値', '@level': '1'}},
#      {'@id': 'area',
#       '@name': '全国',
#       'CLASS': {'@code': '00000', '@name': '全国', '@level': '1'}},
#      {'@id': 'time',
#       '@name': '時間軸（年月日現在）',
#       'CLASS': [{'@code': '2021001212',
#         '@name': '2021年12月',
#         '@level': '4',
#         '@parentCode': '2021001012'},
#        {'@code': '2022000101',
#         '@name': '2022年1月',
#         '@level': '4',
#         '@parentCode': '2022000103'},
#        {'@code': '2022000202',
#         '@name': '2022年2月',
#         '@level': '4',
#         '@parentCode': '2022000103'},
#        {'@code': '2022000303',
#         '@name': '2022年3月',
#         '@level': '4',
#         '@parentCode': '2022000103'},
#        {'@code': '2022000404',
#         '@name': '2022年4月',
#         '@level': '4',
#         '@parentCode': '2022000406'},
#        {'@code': '2022000505',
#         '@name': '2022年5月',
#         '@level': '4',
#         '@parentCode': '2022000406'},
#        {'@code': '2022000606',
#         '@name': '2022年6月',
#         '@level': '4',
#         '@parentCode': '2022000406'},
#        {'@code': '2022000707',
#         '@name': '2022年7月',
#         '@level': '4',
#         '@parentCode': '2022000709'},
#        {'@code': '2022000808',
#         '@name': '2022年8月',
#         '@level': '4',
#         '@parentCode': '2022000709'},
#        {'@code': '2022000909',
#         '@name': '2022年9月',
#         '@level': '4',
#         '@parentCode': '2022000709'},
#        {'@code': '2022001010',
#         '@name': '2022年10月',
#         '@level': '4',
#         '@parentCode': '2022001012'},
#        {'@code': '2022001111',
#         '@name': '2022年11月',
#         '@level': '4',
#         '@parentCode': '2022001012'},
#        {'@code': '2022001212',
#         '@name': '2022年12月',
#         '@level': '4',
#         '@parentCode': '2022001012'},
#        {'@code': '2023000101',
#         '@name': '2023年1月',
#         '@level': '4',
#         '@parentCode': '2023000103'},
#        {'@code': '2023000202',
#         '@name': '2023年2月',
#         '@level': '4',
#         '@parentCode': '2023000103'},
#        {'@code': '2023000303',
#         '@name': '2023年3月',
#         '@level': '4',
#         '@parentCode': '2023000103'},
#        {'@code': '2023000404',
#         '@name': '2023年4月',
#         '@level': '4',
#         '@parentCode': '2023000406'},
#        {'@code': '2023000505',
#         '@name': '2023年5月',
#         '@level': '4',
#         '@parentCode': '2023000406'},
#        {'@code': '2023000606',
#         '@name': '2023年6月',
#         '@level': '4',
#         '@parentCode': '2023000406'},
#        {'@code': '2023000707',
#         '@name': '2023年7月',
#         '@level': '4',
#         '@parentCode': '2023000709'},
#        {'@code': '2023000808',
#         '@name': '2023年8月',
#         '@level': '4',
#         '@parentCode': '2023000709'},
#        {'@code': '2023000909',
#         '@name': '2023年9月',
#         '@level': '4',
#         '@parentCode': '2023000709'},
#        {'@code': '2023001010',
#         '@name': '2023年10月',
#         '@level': '4',
#         '@parentCode': '2023001012'},
#        {'@code': '2023001111',
#         '@name': '2023年11月',
#         '@level': '4',
#         '@parentCode': '2023001012'},
#        {'@code': '2023001212',
#         '@name': '2023年12月',
#         '@level': '4',
#         '@parentCode': '2023001012'},
#        {'@code': '2024000101',
#         '@name': '2024年1月',
#         '@level': '4',
#         '@parentCode': '2024000103'},
#        {'@code': '2024000202',
#         '@name': '2024年2月',
#         '@level': '4',
#         '@parentCode': '2024000103'},
#        {'@code': '2024000303',
#         '@name': '2024年3月',
#         '@level': '4',
#         '@parentCode': '2024000103'},
#        {'@code': '2024000404',
#         '@name': '2024年4月',
#         '@level': '4',
#         '@parentCode': '2024000406'}]}]},
#    'DATA_INF': {'NOTE': [{'@char': '***', '$': '該当数値がないもの'},
#      {'@char': '-', '$': '該当数値がないもの\u3000'}],
#     'VALUE': [{'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '12547'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '12544'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '12534'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '12526'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '12519'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '12505'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '12493'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '12484'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '12478'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '12475'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '12483'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '12485'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '12484'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '12477'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000202',
#       '@unit': '万人',
#       '$': '12463'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000303',
#       '@unit': '万人',
#       '$': '12449'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000404',
#       '@unit': '万人',
#       '$': '12447'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000505',
#       '@unit': '万人',
#       '$': '12450'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000606',
#       '@unit': '万人',
#       '$': '12452'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000707',
#       '@unit': '万人',
#       '$': '12456'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000808',
#       '@unit': '万人',
#       '$': '12454'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000909',
#       '@unit': '万人',
#       '$': '12445'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001010',
#       '@unit': '万人',
#       '$': '12434'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001111',
#       '@unit': '万人',
#       '$': '12431'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001212',
#       '@unit': '万人',
#       '$': '12424'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000101',
#       '@unit': '万人',
#       '$': '12409'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000202',
#       '@unit': '万人',
#       '$': '12399'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000303',
#       '@unit': '万人',
#       '$': '12397'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01000',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000404',
#       '@unit': '万人',
#       '$': '12400'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '437'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '436'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '435'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '433'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '433'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '432'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '430'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '429'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '428'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '426'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '425'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '424'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '423'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '422'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000202',
#       '@unit': '万人',
#       '$': '420'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000303',
#       '@unit': '万人',
#       '$': '418'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000404',
#       '@unit': '万人',
#       '$': '418'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000505',
#       '@unit': '万人',
#       '$': '417'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000606',
#       '@unit': '万人',
#       '$': '415'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000707',
#       '@unit': '万人',
#       '$': '413'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000808',
#       '@unit': '万人',
#       '$': '412'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000909',
#       '@unit': '万人',
#       '$': '411'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001010',
#       '@unit': '万人',
#       '$': '410'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001111',
#       '@unit': '万人',
#       '$': '409'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001212',
#       '@unit': '万人',
#       '$': '407'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000101',
#       '@unit': '万人',
#       '$': '405'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000202',
#       '@unit': '万人',
#       '$': '404'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000303',
#       '@unit': '万人',
#       '$': '403'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01001',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000404',
#       '@unit': '万人',
#       '$': '402'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '503'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '502'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '501'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '500'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '499'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '499'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '498'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '497'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '496'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '496'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '495'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '494'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '494'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '493'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000202',
#       '@unit': '万人',
#       '$': '491'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000303',
#       '@unit': '万人',
#       '$': '490'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000404',
#       '@unit': '万人',
#       '$': '490'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000505',
#       '@unit': '万人',
#       '$': '489'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000606',
#       '@unit': '万人',
#       '$': '489'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000707',
#       '@unit': '万人',
#       '$': '489'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000808',
#       '@unit': '万人',
#       '$': '487'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000909',
#       '@unit': '万人',
#       '$': '485'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001010',
#       '@unit': '万人',
#       '$': '484'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001111',
#       '@unit': '万人',
#       '$': '483'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001212',
#       '@unit': '万人',
#       '$': '482'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000101',
#       '@unit': '万人',
#       '$': '481'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000202',
#       '@unit': '万人',
#       '$': '480'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000303',
#       '@unit': '万人',
#       '$': '479'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01002',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000404',
#       '@unit': '万人',
#       '$': '478'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '535'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '534'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '534'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '534'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '533'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '533'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '532'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '532'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '531'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '531'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '531'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '530'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '530'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '530'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000202',
#       '@unit': '万人',
#       '$': '529'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000303',
#       '@unit': '万人',
#       '$': '528'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000404',
#       '@unit': '万人',
#       '$': '528'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000505',
#       '@unit': '万人',
#       '$': '527'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000606',
#       '@unit': '万人',
#       '$': '527'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000707',
#       '@unit': '万人',
#       '$': '527'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000808',
#       '@unit': '万人',
#       '$': '526'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000909',
#       '@unit': '万人',
#       '$': '525'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001010',
#       '@unit': '万人',
#       '$': '525'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001111',
#       '@unit': '万人',
#       '$': '524'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001212',
#       '@unit': '万人',
#       '$': '524'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000101',
#       '@unit': '万人',
#       '$': '523'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000202',
#       '@unit': '万人',
#       '$': '523'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000303',
#       '@unit': '万人',
#       '$': '522'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01003',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000404',
#       '@unit': '万人',
#       '$': '521'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '559'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '560'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '559'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '557'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '556'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '553'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '552'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '550'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '550'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '550'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '552'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '552'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000202',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000303',
#       '@unit': '万人',
#       '$': '550'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000404',
#       '@unit': '万人',
#       '$': '550'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000505',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000606',
#       '@unit': '万人',
#       '$': '552'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000707',
#       '@unit': '万人',
#       '$': '552'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000808',
#       '@unit': '万人',
#       '$': '552'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000909',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001010',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001111',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001212',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000101',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000202',
#       '@unit': '万人',
#       '$': '551'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000303',
#       '@unit': '万人',
#       '$': '549'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000404',
#       '@unit': '万人',
#       '$': '548'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '626'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '626'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '626'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '626'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '625'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '622'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '619'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '616'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '615'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '614'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '620'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '623'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '624'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '624'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000202',
#       '@unit': '万人',
#       '$': '621'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000303',
#       '@unit': '万人',
#       '$': '620'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000404',
#       '@unit': '万人',
#       '$': '621'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000505',
#       '@unit': '万人',
#       '$': '625'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000606',
#       '@unit': '万人',
#       '$': '628'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000707',
#       '@unit': '万人',
#       '$': '628'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000808',
#       '@unit': '万人',
#       '$': '627'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000909',
#       '@unit': '万人',
#       '$': '626'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001010',
#       '@unit': '万人',
#       '$': '624'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001111',
#       '@unit': '万人',
#       '$': '622'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001212',
#       '@unit': '万人',
#       '$': '622'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000101',
#       '@unit': '万人',
#       '$': '621'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000202',
#       '@unit': '万人',
#       '$': '618'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000303',
#       '@unit': '万人',
#       '$': '620'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000404',
#       '@unit': '万人',
#       '$': '623'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '639'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '639'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '639'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '639'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '638'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '636'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '635'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '634'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '634'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '635'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '637'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '639'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '640'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '639'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000202',
#       '@unit': '万人',
#       '$': '639'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000303',
#       '@unit': '万人',
#       '$': '639'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000404',
#       '@unit': '万人',
#       '$': '641'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000505',
#       '@unit': '万人',
#       '$': '643'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000606',
#       '@unit': '万人',
#       '$': '644'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000707',
#       '@unit': '万人',
#       '$': '645'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000808',
#       '@unit': '万人',
#       '$': '647'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '000',
# ...
#       '@unit': '万人',
#       '$': '283'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001212',
#       '@unit': '万人',
#       '$': '283'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000101',
#       '@unit': '万人',
#       '$': '283'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000202',
#       '@unit': '万人',
#       '$': '282'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000303',
#       '@unit': '万人',
#       '$': '281'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01004',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000404',
#       '@unit': '万人',
#       '$': '281'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '320'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '321'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '321'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '321'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '320'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '318'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '317'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '315'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '315'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '314'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '318'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '319'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '320'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '320'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000202',
#       '@unit': '万人',
#       '$': '319'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000303',
#       '@unit': '万人',
#       '$': '318'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000404',
#       '@unit': '万人',
#       '$': '319'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000505',
#       '@unit': '万人',
#       '$': '321'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000606',
#       '@unit': '万人',
#       '$': '323'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000707',
#       '@unit': '万人',
#       '$': '323'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000808',
#       '@unit': '万人',
#       '$': '323'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000909',
#       '@unit': '万人',
#       '$': '323'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001010',
#       '@unit': '万人',
#       '$': '322'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001111',
#       '@unit': '万人',
#       '$': '321'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001212',
#       '@unit': '万人',
#       '$': '320'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000101',
#       '@unit': '万人',
#       '$': '320'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000202',
#       '@unit': '万人',
#       '$': '318'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000303',
#       '@unit': '万人',
#       '$': '319'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01005',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000404',
#       '@unit': '万人',
#       '$': '321'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '327'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '326'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '325'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '325'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '325'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '327'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000202',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000303',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000404',
#       '@unit': '万人',
#       '$': '329'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000505',
#       '@unit': '万人',
#       '$': '330'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000606',
#       '@unit': '万人',
#       '$': '331'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000707',
#       '@unit': '万人',
#       '$': '332'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000808',
#       '@unit': '万人',
#       '$': '333'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000909',
#       '@unit': '万人',
#       '$': '333'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001010',
#       '@unit': '万人',
#       '$': '333'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001111',
#       '@unit': '万人',
#       '$': '333'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023001212',
#       '@unit': '万人',
#       '$': '333'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000101',
#       '@unit': '万人',
#       '$': '332'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000202',
#       '@unit': '万人',
#       '$': '332'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000303',
#       '@unit': '万人',
#       '$': '333'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01006',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2024000404',
#       '@unit': '万人',
#       '$': '335'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2021001212',
#       '@unit': '万人',
#       '$': '334'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000101',
#       '@unit': '万人',
#       '$': '334'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000202',
#       '@unit': '万人',
#       '$': '333'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000303',
#       '@unit': '万人',
#       '$': '333'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000404',
#       '@unit': '万人',
#       '$': '332'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000505',
#       '@unit': '万人',
#       '$': '331'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000606',
#       '@unit': '万人',
#       '$': '330'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000707',
#       '@unit': '万人',
#       '$': '329'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000808',
#       '@unit': '万人',
#       '$': '329'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022000909',
#       '@unit': '万人',
#       '$': '328'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001010',
#       '@unit': '万人',
#       '$': '329'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001111',
#       '@unit': '万人',
#       '$': '329'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2022001212',
#       '@unit': '万人',
#       '$': '329'},
#      {'@tab': '001',
#       '@cat01': '001',
#       '@cat02': '001',
#       '@cat03': '01007',
#       '@cat04': '01',
#       '@area': '00000',
#       '@time': '2023000101',
#       '@unit': '万人',
#       '$': '328'},
#      ...]}}}}

# %%
data["GET_STATS_DATA"]["STATISTICAL_DATA"]["RESULT_INF"]
# Out:
# {'TOTAL_NUMBER': 2349, 'FROM_NUMBER': 1, 'TO_NUMBER': 2349}

# %%
data["GET_STATS_DATA"]["STATISTICAL_DATA"]["TABLE_INF"]["TITLE"]
# Out:
# {'@no': '001', '$': '概算値 年齢（５歳階級），男女，月別人口－総人口（各月１日現在）-令和２年国勢調査基準-'}

# %%
data["GET_STATS_DATA"]["STATISTICAL_DATA"]["DATA_INF"]["VALUE"][0]
# Out:
# {'@tab': '001',
#  '@cat01': '001',
#  '@cat02': '000',
#  '@cat03': '01000',
#  '@cat04': '01',
#  '@area': '00000',
#  '@time': '2021001212',
#  '@unit': '万人',
#  '$': '12547'}

# %%
len(data["GET_STATS_DATA"]["STATISTICAL_DATA"]["DATA_INF"]["VALUE"])
# Out:
# 2349

# %%
values = data["GET_STATS_DATA"]["STATISTICAL_DATA"]["DATA_INF"]["VALUE"]
for i, d in enumerate(values):
    for k, v in d.items():
        print(k, v, end="|")
    print()
    print("===")
    if i > 1:
        break
# Out:
# @tab 001|@cat01 001|@cat02 000|@cat03 01000|@cat04 01|@area 00000|@time 2021001212|@unit 万人|$ 12547|
# ===
# @tab 001|@cat01 001|@cat02 000|@cat03 01000|@cat04 01|@area 00000|@time 2022000101|@unit 万人|$ 12544|
# ===
# @tab 001|@cat01 001|@cat02 000|@cat03 01000|@cat04 01|@area 00000|@time 2022000202|@unit 万人|$ 12534|
# ===

# %% [markdown]
# ## pandasのDataFrameに変換

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    data["GET_STATS_DATA"]["STATISTICAL_DATA"]["DATA_INF"]["VALUE"]
)
df.head()
# Out:
#   @tab @cat01 @cat02 @cat03 @cat04  @area       @time @unit      $
# 0  001    001    000  01000     01  00000  2021001212    万人  12547
# 1  001    001    000  01000     01  00000  2022000101    万人  12544
# 2  001    001    000  01000     01  00000  2022000202    万人  12534
# 3  001    001    000  01000     01  00000  2022000303    万人  12526
# 4  001    001    000  01000     01  00000  2022000404    万人  12519

# %%
df.shape
# Out:
# (2349, 9)

# %% [markdown]
# # pandasを使って読み込む

# %%
df_raw_json = pd.read_json("data/population-202302.json")
df_raw_json
# Out:
#                                                      GET_STATS_DATA
# RESULT            {'STATUS': 0, 'ERROR_MSG': '正常に終了しました。', 'DATE...
# PARAMETER         {'LANG': 'J', 'STATS_DATA_ID': '0003443838', '...
# STATISTICAL_DATA  {'RESULT_INF': {'TOTAL_NUMBER': 2349, 'FROM_NU...

# %% [markdown]
# ## json_normalize関数を使う

# %%
import json

with open("data/population-202302.json", "r") as f:
    data = json.load(f)

values = data["GET_STATS_DATA"]["STATISTICAL_DATA"]["DATA_INF"]["VALUE"]
df_norm_json = pd.json_normalize(values)

# %%
df_norm_json.head()
# Out:
#   @tab @cat01 @cat02 @cat03 @cat04  @area       @time @unit      $
# 0  001    001    000  01000     01  00000  2021001212    万人  12547
# 1  001    001    000  01000     01  00000  2022000101    万人  12544
# 2  001    001    000  01000     01  00000  2022000202    万人  12534
# 3  001    001    000  01000     01  00000  2022000303    万人  12526
# 4  001    001    000  01000     01  00000  2022000404    万人  12519

# %%
df_norm_json.shape
# Out:
# (2349, 9)

# %%
# カラム名に該当する情報をJSONから取得して、columnsに代入
columns = [
    d["@name"]
    for d in data["GET_STATS_DATA"]["STATISTICAL_DATA"]["CLASS_INF"][
        "CLASS_OBJ"
    ]
]

# JSONからの情報に不足している情報を付与
df_norm_json.columns = columns + ["単位", "人数"]
df_norm_json.head()
# Out:
#   表章項目   人口  男女別 年齢5歳階級 概算値     全国  時間軸（年月日現在）  単位     人数
# 0  001  001  000  01000  01  00000  2021001212  万人  12547
# 1  001  001  000  01000  01  00000  2022000101  万人  12544
# 2  001  001  000  01000  01  00000  2022000202  万人  12534
# 3  001  001  000  01000  01  00000  2022000303  万人  12526
# 4  001  001  000  01000  01  00000  2022000404  万人  12519

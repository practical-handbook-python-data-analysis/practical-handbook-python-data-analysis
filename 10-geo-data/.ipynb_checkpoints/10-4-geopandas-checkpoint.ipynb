# %% [markdown]
# # GeoPandas## GeoDataFrame

# %%
import geopandas as gpd

gdf = gpd.read_file("./data/N03-20220101_25_GML/N03-22_25_220101.geojson")
gdf.head()
# Out:
#   N03_001  N03_002 N03_003 N03_004 N03_007  \
# 0     滋賀県      NaN     NaN     NaN     NaN
# 1     滋賀県      NaN     NaN     大津市   25201
# 2     滋賀県      NaN     NaN     彦根市   25202
# 3     滋賀県      NaN     NaN     長浜市   25203
# 4     滋賀県      NaN     NaN   近江八幡市   25204
#
#                                             geometry
# 0  POLYGON ((136.17602 35.70295, 136.17611 35.702...
# 1  POLYGON ((135.88452 35.28393, 135.88484 35.283...
# 2  POLYGON ((136.24167 35.29628, 136.24408 35.295...
# 3  POLYGON ((136.17602 35.70295, 136.17611 35.702...
# 4  POLYGON ((136.09807 35.19687, 136.09816 35.196...

# %%
gdf = gpd.read_file("./data/N03-20220101_25_GML/")
gdf.head()
# Out:
#   N03_001  N03_002 N03_003 N03_004 N03_007  \
# 0     滋賀県      NaN     NaN     NaN     NaN
# 1     滋賀県      NaN     NaN     大津市   25201
# 2     滋賀県      NaN     NaN     彦根市   25202
# 3     滋賀県      NaN     NaN     長浜市   25203
# 4     滋賀県      NaN     NaN   近江八幡市   25204
#
#                                             geometry
# 0  POLYGON ((136.17602 35.70295, 136.17611 35.702...
# 1  POLYGON ((135.88452 35.28393, 135.88484 35.283...
# 2  POLYGON ((136.24167 35.29628, 136.24408 35.295...
# 3  POLYGON ((136.17602 35.70295, 136.17611 35.702...
# 4  POLYGON ((136.09807 35.19687, 136.09816 35.196...

# %% [markdown]
# ## .cxインデクサ

# %%
gdf.cx[136.2:136.4, 35.5:35.6]
# Out:
#    N03_001  N03_002 N03_003 N03_004 N03_007  \
# 0      滋賀県      NaN     NaN     NaN     NaN
# 3      滋賀県      NaN     NaN     長浜市   25203
# 13     滋賀県      NaN     NaN     米原市   25214
#
#                                              geometry
# 0   POLYGON ((136.17602 35.70295, 136.17611 35.702...
# 3   POLYGON ((136.17602 35.70295, 136.17611 35.702...
# 13  POLYGON ((136.36961 35.55895, 136.37013 35.558...

# %% [markdown]
# ## GeoSeriesの処理

# %%
gdf.dtypes
# Out:
# N03_001       object
# N03_002      float64
# N03_003       object
# N03_004       object
# N03_007       object
# geometry    geometry
# dtype: object

# %%
geoseries = gdf.loc[:, "geometry"]
type(geoseries)
# Out:
# geopandas.geoseries.GeoSeries

# %%
type(geoseries[0])
# Out:
# shapely.geometry.polygon.Polygon

# %%
geoseries[0]
# Out:
# <POLYGON ((136.176 35.703, 136.176 35.703, 136.176 35.703, 136.176 35.703, 1...>

# %%
geoseries[0].geom_type
# Out:
# 'Polygon'

# %%
geoseries.geom_type.head()
# Out:
# 0    Polygon
# 1    Polygon
# 2    Polygon
# 3    Polygon
# 4    Polygon
# dtype: object

# %%
geoseries.plot()
# Out:
# <Axes: >

# %%
geoseries.length.head(3)
# Out:
# /tmp/ipykernel_11651/3314103464.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'length' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geoseries.length.head(3)
# 0    4.172540
# 1    1.741525
# 2    0.896302
# dtype: float64

# %%
geoseries_transformed = geoseries.to_crs("EPSG:6674")
geoseries_transformed.length.head(3)
# Out:
# 0    421133.400718
# 1    176753.577131
# 2     89430.450606
# dtype: float64

# %%
geoseries_transformed.area.head(3)
# Out:
# 0    4.016153e+09
# 1    4.644209e+08
# 2    1.968331e+08
# dtype: float64

# %% [markdown]
# # 地理空間データの可視化

# %% [markdown]
# ## ポイントの可視化

# %%
import pandas as pd

itami_wifi = pd.read_csv("data/282073publicwirelesslan202204.csv")
itami_wifi.iloc[:3, 3:10]
# Out:
#            名称          名称_カナ                名称_英語              住所  方書  \
# 0      有岡城跡公園  アリオカジョウセキコウエン  Arioka Castle Ruins    兵庫県伊丹市伊丹1-16 NaN
# 1    市バス総合案内所  シバスソウゴウアンナイジョ    City Bus Terminal  兵庫県伊丹市西台1-1-24 NaN
# 2  市立伊丹ミュージアム   シリツイタミミュージアム    Itami City Museum    兵庫県伊丹市宮ノ前2-5 NaN
#
#           緯度          経度
# 0  34.780851  135.421042
# 1  34.780171  135.413086
# 2  34.781996  135.417263

# %%
itami_center = itami_wifi.loc[:, ["緯度", "経度"]].mean()
itami_center
# Out:
# 緯度     34.781261
# 経度    135.422682
# dtype: float64

# %%
import folium

itami_wifi_map = folium.Map(
    location=itami_center,
    zoom_start=15.2,
    width=800,
    height=400,
)
itami_wifi_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad5ac40927eabe8b1bc0b74304761d8b {
#                     position: relative;
#                     width: 800.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad5ac40927eabe8b1bc0b74304761d8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad5ac40927eabe8b1bc0b74304761d8b = L.map(
#                 &quot;map_ad5ac40927eabe8b1bc0b74304761d8b&quot;,
#                 {
#                     center: [34.78126148, 135.42268199999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27a9e0a877e3218e6d241d155173a90e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
marker = folium.Marker(location=itami_wifi.loc[0, ["緯度", "経度"]])
marker.add_to(itami_wifi_map)
itami_wifi_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad5ac40927eabe8b1bc0b74304761d8b {
#                     position: relative;
#                     width: 800.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad5ac40927eabe8b1bc0b74304761d8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad5ac40927eabe8b1bc0b74304761d8b = L.map(
#                 &quot;map_ad5ac40927eabe8b1bc0b74304761d8b&quot;,
#                 {
#                     center: [34.78126148, 135.42268199999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27a9e0a877e3218e6d241d155173a90e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_d13d8c54d942c8ed4de8744f5c370630 = L.marker(
#                 [34.780851, 135.421042],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
itami_wifi.loc[:, ["緯度", "経度"]].apply(
    lambda x: folium.Marker(location=x).add_to(itami_wifi_map),
    axis=1,
)
itami_wifi_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad5ac40927eabe8b1bc0b74304761d8b {
#                     position: relative;
#                     width: 800.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad5ac40927eabe8b1bc0b74304761d8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad5ac40927eabe8b1bc0b74304761d8b = L.map(
#                 &quot;map_ad5ac40927eabe8b1bc0b74304761d8b&quot;,
#                 {
#                     center: [34.78126148, 135.42268199999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27a9e0a877e3218e6d241d155173a90e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_d13d8c54d942c8ed4de8744f5c370630 = L.marker(
#                 [34.780851, 135.421042],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_6473782b9c18c8455c546bd964acc2a2 = L.marker(
#                 [34.780851, 135.421042],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_b698a119a9cd2aef365c268cd92e7e93 = L.marker(
#                 [34.780171, 135.413086],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_fa3822d661571ffc3081511a830ef20a = L.marker(
#                 [34.781996, 135.417263],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_2c85b5b54d3546e92145694a0342ba44 = L.marker(
#                 [34.782622, 135.417333],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_1e850a3d7e8a5819437836d8caddd355 = L.marker(
#                 [34.78212, 135.416952],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_ef434b1e07ae88305cc7261c11a66dbe = L.marker(
#                 [34.782049, 135.417108],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_926571759277cb28300f2cd992a7b484 = L.marker(
#                 [34.782177, 135.417387],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_705d0b361b402f2c14f08bff010c77da = L.marker(
#                 [34.782428, 135.417387],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_3b68d9dc657f9a02d59e0b4283d1b8bb = L.marker(
#                 [34.782543, 135.417376],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_86de25550ac1942f8204cadc607e42fd = L.marker(
#                 [34.782344, 135.417392],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_2f0342a0c1e3d981283e5221e8f47b58 = L.marker(
#                 [34.782344, 135.417392],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_af5be28d00a16508931fa7641ef1fc86 = L.marker(
#                 [34.782344, 135.417392],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_d0f792d7ab78e792b47b732c23beb9d1 = L.marker(
#                 [34.782344, 135.417392],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_11a9c97c3c7986364132b06d5b3b0c74 = L.marker(
#                 [34.782344, 135.417392],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_935eb904125aa9714800a4f07a19d1b0 = L.marker(
#                 [34.780816, 135.416242],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_05f4551ce053e16a948726f070998b4c = L.marker(
#                 [34.781096, 135.417254],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_4224a38543e0e7c112ac29567fbf959d = L.marker(
#                 [34.781083, 135.417539],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_2104f9994ca2edd2a5eaa1eca37e22f8 = L.marker(
#                 [34.780684, 135.421846],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_b9323f5cb3915e141599cb38e28b0b77 = L.marker(
#                 [34.781987, 135.436028],
#                 {}
#             ).addTo(map_ad5ac40927eabe8b1bc0b74304761d8b);
#
#
#             var marker_043a5145da0d439e7c220413b6f

# %%
import geopandas as gpd

land_price_gdf = (
    gpd.read_file(
        "https://nlftp.mlit.go.jp/ksj/gml/data/L01/L01-22/L01-22_25_GML.zip"
    )
    .groupby("L01_005")
    .get_group("2022")
)
land_price_gdf.loc[:3, ["L01_006", "L01_023", "geometry"]]
# Out:
#    L01_006 L01_023                    geometry
# 0    61400      大津  POINT (135.91198 35.10887)
# 1    94200      大津  POINT (135.91556 35.12295)
# 2    41800      大津  POINT (135.90057 35.09722)
# 3    75400      大津  POINT (135.87669 35.07480)

# %%
land_price = land_price_gdf.apply(
    lambda s: pd.Series(
        (
            s["geometry"].y,
            s["geometry"].x,
            s["L01_006"],
        )
    ),
    axis=1,
).values
land_price[:3]
# Out:
# array([[3.51088681e+01, 1.35911983e+02, 6.14000000e+04],
#        [3.51229489e+01, 1.35915560e+02, 9.42000000e+04],
#        [3.50972189e+01, 1.35900566e+02, 4.18000000e+04]])

# %%
from folium.plugins import HeatMap

shiga_center = (
    land_price_gdf.loc[:, "geometry"].y.mean(),
    land_price_gdf.loc[:, "geometry"].x.mean(),
)
land_price_map = folium.Map(
    location=shiga_center,
    zoom_start=10,
)
HeatMap(
    data=land_price,
    radius=12,
).add_to(land_price_map)
land_price_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a2cf3c78ba3ea95bfbf47686a97ef44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a2cf3c78ba3ea95bfbf47686a97ef44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a2cf3c78ba3ea95bfbf47686a97ef44 = L.map(
#                 &quot;map_8a2cf3c78ba3ea95bfbf47686a97ef44&quot;,
#                 {
#                     center: [35.11964417791907, 136.08411006329482],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9df6b4cf8e29833c5f4d6590c9073095 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a2cf3c78ba3ea95bfbf47686a97ef44);
#
#
#             var heat_map_3959d43a1996aaf853407034fe96a492 = L.heatLayer(
#                 [[35.10886806, 135.9119831, 61400.0], [35.12294889, 135.91556, 94200.0], [35.09721889, 135.9005661, 41800.0], [35.074805, 135.8766939, 75400.0], [35.25188389, 135.9729869, 16900.0], [35.05280611, 135.8736386, 84800.0], [35.03290194, 135.8559769, 94500.0], [35.03439694, 135.8624781, 95600.0], [35.02013306, 135.8596081, 68500.0], [34.98179306, 135.9379011, 111000.0], [34.99180611, 135.8300061, 94900.0], [35.11056, 135.9193, 49000.0], [34.99507083, 135.8748489, 115000.0], [35.00326111, 135.8696181, 165000.0], [35.00897694, 135.8562269, 99800.0], [35.00110806, 135.8688639, 143000.0], [34.98925111, 135.8797619, 83800.0], [34.98427389, 135.91294, 116000.0], [35.14516111, 135.9175089, 47000.0], [34.95753, 135.8914411, 54000.0], [34.94123306, 135.9040439, 61900.0], [34.946915, 135.9037011, 57300.0], [34.97089389, 135.9077789, 82600.0], [34.966005, 135.9113731, 92000.0], [34.98383611, 135.92873, 106000.0], [34.94416194, 135.9164131, 48100.0], [34.98821806, 135.9167369, 119000.0], [34.93418694, 135.934085, 44800.0], [34.96763, 135.8954511, 86300.0], [34.97591389, 135.9111011, 97100.0], [34.97545, 135.97309, 94500.0], [34.98363194, 135.8917131, 94700.0], [35.099995, 135.894975, 80200.0], [35.20206, 135.9215519, 20300.0], [35.05536, 135.8757781, 49900.0], [34.99664889, 135.838375, 63900.0], [34.96902111, 135.9032339, 72500.0], [35.11015694, 135.8928639, 70200.0], [35.02934806, 135.8335269, 25100.0], [35.00274306, 135.8756761, 143000.0], [35.02613111, 135.8482431, 71500.0], [34.96011694, 135.9119731, 67400.0], [34.97013389, 135.915195, 86300.0], [35.00641, 135.8656831, 146000.0], [34.933345, 135.9041439, 32900.0], [35.159495, 135.9201911, 36400.0], [35.00719306, 135.8634039, 239000.0], [34.97297694, 135.9349231, 110000.0], [35.14275389, 135.8769989, 18900.0], [35.09038889, 135.8836611, 20900.0], [35.13547694, 135.8943481, 27800.0], [34.94514389, 135.89203, 24800.0], [34.93139806, 135.923555, 23500.0], [34.96022, 135.9592011, 24600.0], [34.99439694, 135.8534739, 43100.0], [35.16223111, 135.9180339, 31400.0], [35.04966417, 135.86583, 98000.0], [35.11692389, 135.910555, 88700.0], [35.11972028, 135.9194319, 88000.0], [35.00728611, 135.867715, 212000.0], [35.02686694, 135.8643261, 119000.0], [35.04885889, 135.86536, 104000.0], [35.13463889, 135.9241789, 66900.0], [35.00371389, 135.8659231, 354000.0], [34.98611, 135.9252411, 259000.0], [34.99579, 135.8829239, 107000.0], [35.00454, 135.8709069, 196000.0], [35.02331611, 135.8577569, 175000.0], [35.005335, 135.8809389, 259000.0], [35.16199111, 135.9231339, 59800.0], [35.10240611, 135.9037211, 60600.0], [34.97913972, 135.9015244, 249000.0], [34.98423889, 135.924655, 151000.0], [34.97293111, 135.9080969, 93700.0], [34.97908889, 135.9046519, 143000.0], [34.99999806, 135.8811489, 263000.0], [34.99429306, 135.92059, 103000.0], [35.00922889, 135.8609181, 119000.0], [34.97688111, 135.9018669, 159000.0], [34.98608111, 135.9091161, 132000.0], [34.98148806, 135.8972619, 49600.0], [34.93175028, 135.9259231, 25900.0], [35.20581111, 136.20066, 49900.0], [35.22842694, 136.2195811, 52700.0], [35.27302694, 136.24935, 54600.0], [35.24872889, 136.2752069, 34200.0], [35.28395389, 136.2488581, 44100.0], [35.24648194, 136.2464119, 68700.0], [35.23258194, 136.2563769, 35500.0], [35.25187389, 136.2612911, 38500.0], [35.22291111, 136.226155, 53400.0], [35.27971111, 136.2870139, 34400.0], [35.24986611, 136.2488381, 43400.0], [35.28080694, 136.28335, 24000.0], [35.25582694, 136.2427111, 53700.0], [35.22489611, 136.2336661, 28000.0], [35.26532111, 136.238615, 54400.0], [35.25755194, 136.23347, 56100.0], [35.22642389, 136.172125, 14500.0], [35.29056194, 136.2780411, 13200.0], [35.25566611, 136.2247239, 31300.0], [35.27397389, 136.2624189, 74400.0], [35.24762389, 136.2479489, 68800.0], [35.27207889, 136.2622831, 125000.0], [35.27105083, 136.2517692, 90000.0],

# %% [markdown]
# ## ラインの可視化

# %%
minx, miny = land_price_gdf.loc[:, "geometry"].bounds.min()[
    ["minx", "miny"]
]
maxx, maxy = land_price_gdf.loc[:, "geometry"].bounds.max()[
    ["maxx", "maxy"]
]
rail_gdf = gpd.read_file(
    "https://nlftp.mlit.go.jp/ksj/gml/data/N02/N02-21/N02-21_GML.zip"
).cx[minx:maxx, miny:maxy]
rail_gdf.head()
# Out:
#      N02_001 N02_002 N02_003 N02_004  \
# 1381      21       4     京津線  京阪電気鉄道
# 1382      21       4     京津線  京阪電気鉄道
# 1385      21       4     京津線  京阪電気鉄道
# 1387      21       4     京津線  京阪電気鉄道
# 1388      21       4     京津線  京阪電気鉄道
#
#                                                geometry
# 1381  LINESTRING (135.86366 35.01145, 135.86436 35.0...
# 1382  LINESTRING (135.86366 35.01145, 135.86340 35.0...
# 1385  LINESTRING (135.83788 34.99126, 135.83712 34.9...
# 1387  LINESTRING (135.83712 34.99145, 135.83601 34.9...
# 1388  LINESTRING (135.85273 34.99438, 135.85251 34.9...

# %%
# 京津線のデータを抽出
keishinsen = rail_gdf.groupby("N02_003")["geometry"].get_group("京津線")
# 中心となる座標
keishinsen_center = (
    keishinsen.map(lambda p: p.centroid.y).mean(),
    keishinsen.map(lambda p: p.centroid.x).mean(),
)
keishinsen_center
# Out:
# (35.00045506603767, 135.8527293845286)

# %%
import numpy as np


keishinsen_map = folium.Map(
    location=keishinsen_center,
    zoom_start=14,
)
keishinsen.apply(
    lambda s: folium.PolyLine(
        # 緯度, 経度の順番に変換、fliplr関数で順序を反転
        locations=np.fliplr(s.coords),
        weight=15  # 線の太さ
    ).add_to(keishinsen_map)
)
keishinsen_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b70edd8594eddd8d1a23453c2a47ca4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b70edd8594eddd8d1a23453c2a47ca4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b70edd8594eddd8d1a23453c2a47ca4 = L.map(
#                 &quot;map_6b70edd8594eddd8d1a23453c2a47ca4&quot;,
#                 {
#                     center: [35.00045506603767, 135.8527293845286],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2a6e8d6dfe5f16dee6669d470a93024 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b70edd8594eddd8d1a23453c2a47ca4);
#
#
#             var poly_line_af2a121726c6d32867f9811abdef85dc = L.polyline(
#                 [[35.01145, 135.86366], [35.01114, 135.86436]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 15}
#             ).addTo(map_6b70edd8594eddd8d1a23453c2a47ca4);
#
#
#             var poly_line_05ffccf78fbb4d7350dd7f775451f318 = L.polyline(
#                 [[35.01145, 135.86366], [35.01152, 135.8634]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 15}
#             ).addTo(map_6b70edd8594eddd8d1a23453c2a47ca4);
#
#
#             var poly_line_fc65e16f7af4d8a0c3f2f2c0a40b044b = L.polyline(
#                 [[34.99126, 135.83788], [34.99145, 135.83712]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 15}
#             ).addTo(map_6b70edd8594eddd8d1a23453c2a47ca4);
#
#
#             var poly_line_6d070f89860b0c7cbdcbe480cfa9839b = L.polyline(
#                 [[34.99145, 135.83712], [34.99173, 135.83601], [34.99187, 135.83518], [34.99187, 135.83509], [34.99186, 135.83479], [34.99217, 135.83257], [34.99218, 135.83234], [34.99225, 135.83092], [34.99225, 135.83], [34.99225, 135.82896], [34.99226, 135.828], [34.99224, 135.82778], [34.99221, 135.8275], [34.99196, 135.82467], [34.99193, 135.82437]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 15}
#             ).addTo(map_6b70edd8594eddd8d1a23453c2a47ca4);
#
#
#             var poly_line_24bdeb20b9a6836ef0ada67b54d899ee = L.polyline(
#                 [[34.99438, 135.85273], [34.99433, 135.85251], [34.99429, 135.85236], [34.99408, 135.85202], [34.99303, 135.85042], [34.99224, 135.8492], [34.99207, 135.84882], [34.99189, 135.84826], [34.99147, 135.84663], [34.9903, 135.84213], [34.99027, 135.84179], [34.99057, 135.84059], [34.99068, 135.84016], [34.99126, 135.83788]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&qu

# %%
rail_map = folium.Map(
    location=shiga_center,
    zoom_start=10,
)
folium.features.GeoJson(rail_gdf).add_to(rail_map)
rail_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_130d8152c797b6cd126de9116c2a7ad1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_130d8152c797b6cd126de9116c2a7ad1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_130d8152c797b6cd126de9116c2a7ad1 = L.map(
#                 &quot;map_130d8152c797b6cd126de9116c2a7ad1&quot;,
#                 {
#                     center: [35.11964417791907, 136.08411006329482],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_943c8bfda0c0b5af56bd3ec279dd8a36 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_130d8152c797b6cd126de9116c2a7ad1);
#
#
#
#         function geo_json_c4eb159a509d82c8e920e852088db234_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c4eb159a509d82c8e920e852088db234 = L.geoJson(null, {
#                 onEachFeature: geo_json_c4eb159a509d82c8e920e852088db234_onEachFeature,
#
#         });
#
#         function geo_json_c4eb159a509d82c8e920e852088db234_add (data) {
#             geo_json_c4eb159a509d82c8e920e852088db234
#                 .addData(data)
#                 .addTo(map_130d8152c797b6cd126de9116c2a7ad1);
#         }
#             geo_json_c4eb159a509d82c8e920e852088db234_add({&quot;bbox&quot;: [135.76127, 34.84971, 136.68425, 35.53692], &quot;features&quot;: [{&quot;bbox&quot;: [135.86366, 35.01114, 135.86436, 35.01145], &quot;geometry&quot;: {&quot;coordinates&quot;: [[135.86366, 35.01145], [135.86436, 35.01114]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1381&quot;, &quot;properties&quot;: {&quot;N02_001&quot;: &quot;21&quot;, &quot;N02_002&quot;: &quot;4&quot;, &quot;N02_003&quot;: &quot;\u4eac\u6d25\u7dda&quot;, &quot;N02_004&quot;: &quot;\u4eac\u962a\u96fb\u6c17\u9244\u9053&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.8634, 35.01145, 135.86366, 35.01152], &quot;geometry&quot;: {&quot;coordinates&quot;: [[135.86366, 35.01145], [135.8634, 35.01152]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1382&quot;, &quot;properties&quot;: {&quot;N02_001&quot;: &quot;21&quot;, &quot;N02_002&quot;: &quot;4&quot;, &quot;N02_003&quot;: &quot;\u4eac\u6d25\u7dda&quot;, &quot;N02_004&quot;: &quot;\u4eac\u962a\u96fb\u6c17\u9244\u9053&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.83712, 34.99126, 135.83788, 34.99145], &quot;geometry&quot;: {&quot;coordinates&quot;: [[135.83788, 34.99126], [135.83712, 34.99145]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1385&quot;, &quot;properties&quot;: {&quot;N02_001&quot;: &quot;21&quot;, &quot;N02_002&quot;: &quot;4&quot;, &quot;N02_003&quot;: &quot;\u4eac\u6d25\u7dda&quot;, &quot;N02_004&quot;: &quot;\u4eac\u962a\u96fb\u6c17\u9244\u9053&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.82437, 34.99145, 135.83712, 34.99226], &quot;geometry&quot;: {&quot;coordinates&quot;: [[135.83712, 34.99145], [135.83601, 34.99173], [135.83518, 34.99187], [135.83509, 34.99187], [135.83479, 34.99186], [135.83257, 34.99217], [135.83234, 34.99218], [135.83092, 34.99225], [135.83, 34.99225], [135.82896, 34.99225], [135.828, 34.99226], [135.82778, 34.99224], [135.8275, 34.99221], [135.82467, 34.99196], [135.82437, 34.99193]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1387&quot;, &quot;properties&quot;: {&quot;N02_001&quot;: &quot;21&quot;, &quot;N02_002&quot;: &quot;4&quot;, &quot;N02_003&quot;: &quot;\u4eac\u6d25\u7dda&quot;, &quot;N02_004&quot;: &quot;\u4eac\u962a\u96fb\u6c17\u9244\u9053&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.83788, 34.99027, 135.85273, 34.99438], &quot;geometry&quot;: {&quot;coordinates&quot;: [[135.85273, 34.99438], [135.85251, 34.99433], [135.85236, 34.99429], [135.85202, 34.99408], [135.85042, 34.99303], [135.8492, 34.99224], [135.84882, 34.99207], [135.84826, 34.99189], [135.84663, 34.99147], [135.84213, 34.9903], [135.84179, 34.99027], [135.84059, 34.99057], [135.84016, 34.99068], [135.83788, 34.99126]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1388&quot;, &quot;properties&quot;: {&quot;N02_001&quot;: &quot;21&quot;, &quot;N02_002&quot;: &quot;4&quot;, &quot;N02_003&quot;: &quot;\u4eac\u6d25\u7dda&quot;, &quot;N02_004&quot;: &quot;\u4eac\u962a\u96fb\u6c17\u9244\u9053&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.8536, 34.99409, 135.86004, 35.00486], &quot;geometry&quot;: {&quot;coordinates&quot;: [[135.8536, 34.99424], [135.85381, 34.99418], [135.85431, 34.9941], [135.85459, 34.99409], [135.85489, 34.99413], [135.85504, 34.99417], [135.85551, 34.99429], [135.85561, 34.99444], [135.85804,

# %% [markdown]
# ## ポリゴンの可視化

# %%
did_gdf = gpd.read_file("./data/A16-15_25_DID.geojson")
did_gdf.head()
# Out:
#      DIDid  行政コード 市町村名称  DID符号      人口     面積    前回人口   前回面積  人口割合  面積割合  \
# 0  2520101  25201   大津市      1  137645  20.56  136520  20.48  40.4   4.4
# 1  2520101  25201   大津市      1  137645  20.56  136520  20.48  40.4   4.4
# 2  2520102  25201   大津市      2   60475   8.01   56260   7.33  17.7   1.7
# 3  2520103  25201   大津市      3   19646   2.95   18661   2.77   5.8   0.6
# 4  2520103  25201   大津市      3   19646   2.95   18661   2.77   5.8   0.6
#
#    調査年度                                           geometry
# 0  2015  POLYGON ((135.86910 35.08068, 135.86876 35.080...
# 1  2015  POLYGON ((135.86910 35.08068, 135.87006 35.080...
# 2  2015  POLYGON ((135.91999 34.99576, 135.92019 34.996...
# 3  2015  POLYGON ((135.90632 35.10916, 135.90570 35.109...
# 4  2015  POLYGON ((135.90632 35.10916, 135.90682 35.108...

# %%
did_map = folium.Map(
    location=shiga_center,
    zoom_start=10,
)
folium.GeoJson(did_gdf).add_to(did_map)
did_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59f8f0a6dd41233b8a5880f751f89ee9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59f8f0a6dd41233b8a5880f751f89ee9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59f8f0a6dd41233b8a5880f751f89ee9 = L.map(
#                 &quot;map_59f8f0a6dd41233b8a5880f751f89ee9&quot;,
#                 {
#                     center: [35.11964417791907, 136.08411006329482],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_131b16b4ec36c4990e027a099e456dd7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_59f8f0a6dd41233b8a5880f751f89ee9);
#
#
#
#         function geo_json_96c7f95f934e88e253e180c795a693fc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_96c7f95f934e88e253e180c795a693fc = L.geoJson(null, {
#                 onEachFeature: geo_json_96c7f95f934e88e253e180c795a693fc_onEachFeature,
#
#         });
#
#         function geo_json_96c7f95f934e88e253e180c795a693fc_add (data) {
#             geo_json_96c7f95f934e88e253e180c795a693fc
#                 .addData(data)
#                 .addTo(map_59f8f0a6dd41233b8a5880f751f89ee9);
#         }
#             geo_json_96c7f95f934e88e253e180c795a693fc_add({&quot;bbox&quot;: [135.84660738, 34.93182055, 136.29847253, 35.40329895], &quot;features&quot;: [{&quot;bbox&quot;: [135.86819349, 35.08013973, 135.86909907, 35.08130626], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[135.86909907, 35.08067888], [135.86875891, 35.08016821], [135.86873337, 35.08013973], [135.86819349, 35.0803493], [135.8683807, 35.08065501], [135.86820915, 35.08071989], [135.86852958, 35.08129209], [135.8686703, 35.08130626], [135.86902202, 35.08125171], [135.86906339, 35.08112329], [135.86909907, 35.08067888]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;DIDid&quot;: 2520101, &quot;DID\u7b26\u53f7&quot;: 1, &quot;\u4eba\u53e3&quot;: 137645, &quot;\u4eba\u53e3\u5272\u5408&quot;: 40.4, &quot;\u524d\u56de\u4eba\u53e3&quot;: 136520, &quot;\u524d\u56de\u9762\u7a4d&quot;: 20.48, &quot;\u5e02\u753a\u6751\u540d\u79f0&quot;: &quot;\u5927\u6d25\u5e02&quot;, &quot;\u884c\u653f\u30b3\u30fc\u30c9&quot;: &quot;25201&quot;, &quot;\u8abf\u67fb\u5e74\u5ea6&quot;: 2015, &quot;\u9762\u7a4d&quot;: 20.56, &quot;\u9762\u7a4d\u5272\u5408&quot;: 4.4}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.84660738, 34.96030625, 135.90629127, 35.08598696], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[135.86909907, 35.08067888], [135.87005759, 35.08096386], [135.87013986, 35.08099437], [135.87044425, 35.08110287], [135.87060474, 35.08111318], [135.87076942, 35.08108631], [135.87117917, 35.08093294], [135.87119371, 35.08084337], [135.87097013, 35.08054376], [135.87093975, 35.08049528], [135.87094456, 35.08043155], [135.87099086, 35.08027694], [135.87117212, 35.08016551], [135.87159473, 35.07968432], [135.87171447, 35.07942754], [135.87181552, 35.07929074], [135.87191879, 35.07904069], [135.87200341, 35.0788836], [135.8722342, 35.07867087], [135.87256105, 35.07865481], [135.87239331, 35.07958375], [135.87178302, 35.08034708], [135.87191034, 35.08052299], [135.87257148, 35.08014867], [135.87277863, 35.08003825], [135.87377753, 35.07949588], [135.87389132, 35.07964953], [135.87398491, 35.08035951], [135.87438004, 35.08034639], [135.87454406, 35.0802205], [135.87486348, 35.08000455], [135.8747879, 35.07994771], [135.87566257, 35.07910935], [135.8758668, 35.0789204], [135.87640023, 35.07858839], [135.87651221, 35.07849935], [135.87665415, 35.07866414], [135.87689668, 35.07885369], [135.87669265, 35.07906821], [135.87640692, 35.07936082], [135.87633593, 35.07931434], [135.87630019, 35.07912845], [135.87614806, 35.07918259], [135.87614174, 35.07917773], [135.87604214, 35.07910023], [135.87589046, 35.07926656], [135.87599931, 35.07934167], [135.87570283, 35.07968138], [135.87581137, 35.07976037], [135.8757165, 35.07985669], [135.87580649, 35.07993269], [135.87576924, 35.08008139], [135.87541597, 35.08012406], [135.87520836, 35.08034872], [135.87518999, 35.08041751], [135.87506409, 35.08054506], [135.87508228, 35.08057374], [135.87510822, 35.08059989], [135.87517338, 35.08064961], [135.87518966, 35.08076583], [135.87514337, 35.08092797], [135.87502802, 35.08106567], [135.87485344, 35.08121148], [135.87466035, 35.08125664], [135.87444194, 35.08142544], [135.8741703, 35.0814353], [135.87412927, 35.08151744], [135.87408145, 35.0815743], [135.87429856, 35.08158262], [135.87428683, 35.08194072], [135.87390406, 35.08194377], [135.8735953, 35.08199409], [135.87355407, 35.08204137], [135.87354978, 35.08231631], [135.87368339, 35.082434

# %%
did_choroplethmap = folium.Map(
    location=shiga_center,
    zoom_start=10,
)
folium.features.Choropleth(
    geo_data=did_gdf,
    data=did_gdf,
    key_on="feature.properties.DIDid",
    columns=["DIDid", "人口"],
    legend_name="人口",
).add_to(did_choroplethmap)
did_choroplethmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e103854822bb4061f45e15e243e113b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e103854822bb4061f45e15e243e113b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e103854822bb4061f45e15e243e113b3 = L.map(
#                 &quot;map_e103854822bb4061f45e15e243e113b3&quot;,
#                 {
#                     center: [35.11964417791907, 136.08411006329482],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5edfd819f6e11c78846f71695a7c907 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e103854822bb4061f45e15e243e113b3);
#
#
#             var choropleth_60417a8eaecc3d7258549b0d957d4cea = L.featureGroup(
#                 {}
#             ).addTo(map_e103854822bb4061f45e15e243e113b3);
#
#
#         function geo_json_1ef45acdb78e962b895d09affdbf848e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;10&quot;: case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;20&quot;: case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;18&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_1ef45acdb78e962b895d09affdbf848e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1ef45acdb78e962b895d09affdbf848e = L.geoJson(null, {
#                 onEachFeature: geo_json_1ef45acdb78e962b895d09affdbf848e_onEachFeature,
#
#                 style: geo_json_1ef45acdb78e962b895d09affdbf848e_styler,
#         });
#
#         function geo_json_1ef45acdb78e962b895d09affdbf848e_add (data) {
#             geo_json_1ef45acdb78e962b895d09affdbf848e
#                 .addData(data)
#                 .addTo(choropleth_60417a8eaecc3d7258549b0d957d4cea);
#         }
#             geo_json_1ef45acdb78e962b895d09affdbf848e_add({&quot;bbox&quot;: [135.84660738, 34.93182055, 136.29847253, 35.40329895], &quot;features&quot;: [{&quot;bbox&quot;: [135.86819349, 35.08013973, 135.86909907, 35.08130626], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[135.86909907, 35.08067888], [135.86875891, 35.08016821], [135.86873337, 35.08013973], [135.86819349, 35.0803493], [135.8683807, 35.08065501], [135.86820915, 35.08071989], [135.86852958, 35.08129209], [135.8686703, 35.08130626], [135.86902202, 35.08125171], [135.86906339, 35.08112329], [135.86909907, 35.08067888]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;DIDid&quot;: 2520101, &quot;DID\u7b26\u53f7&quot;: 1, &quot;\u4eba\u53e3&quot;: 137645, &quot;\u4eba\u53e3\u5272\u5408&quot;: 40.4, &quot;\u524d\u56de\u4eba\u53e3&quot;: 136520, &quot;\u524d\u56de\u9762\u7a4d&quot;: 20.48, &quot;\u5e02\u753a\u6751\u540d\u79f0&quot;: &quot;\u5927\u6d25\u5e02&quot;, &quot;\u884c\u653f\u30b3\u30fc\u30c9&quot;: &quot;25201&quot;, &quot;\u8abf\u67fb\u5e74\u5ea6&quot;: 2015, &quot;\u9762\u7a4d&quot;: 20.56, &quot;\u9762\u7a4d\u5272\u5408&quot;: 4.4}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.84660738, 34.96030625, 135.90629127, 35.08598696], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[135.86909907, 35.08067888], [135.87005759, 35.08096386], [135.87013986, 35.08099437], [135.87044425, 35.08110287], [135.87060474, 35.08111318], [135.87076942, 35.08108631], [135.87117917, 35.08093294], [135.87119371, 35.08084337], [135.87097013, 35.08054376], [135.87093975, 35.08049528], [135.87094456, 35.08043155], [135.87099086, 35.08027694], [135.87117212, 35.08016551], [135.871
